# %%
# !pip install citipy==0.0.5
# Out:
# Requirement already satisfied: citipy==0.0.5 in c:\users\banks\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\banks\anaconda3\envs\pythondata\lib\site-packages (from citipy==0.0.5) (0.16)

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\banks\anaconda3\envs\pythondata\lib\site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\banks\anaconda3\envs\pythondata\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\banks\anaconda3\envs\pythondata\lib\site-packages (from requests) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\banks\anaconda3\envs\pythondata\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\banks\anaconda3\envs\pythondata\lib\site-packages (from requests) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
from citipy import citipy
import config
from config import w_api
from random import uniform
import numpy as np
import pandas as pd
import requests
import random
import json
from pprint import pprint
import matplotlib.pyplot as plt 
from scipy.stats import linregress

# %%
# Out:
# 'e23a8eca03f375a41115bf69cb4a72af'

# %%
metric = "Fahrenheit"

city_url = 'https://pypi.python.org/pypi/citipy'
url = 'http://api.openweathermap.org/data/2.5/weather?'
print(requests.get(city_url))
print(requests.get(url))
# Out:
# <Response [200]>
# <Response [401]>

# %%
response = requests.get(city_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-6-d41f5b93d931> in <module>
# ----> 1 response = requests.get(city_url).json()
#       2 print(json.dumps(response, indent=4, sort_keys=True))
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\anaconda3\envs\PythonData\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\envs\PythonData\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\envs\PythonData\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 7 column 1 (char 6)

# %%
#Run city search 
cities = list()
weather = list()
dup_cities = list()
weatherless_cities = set()
while len(weather) < 500:
    
    long = round(uniform(-30,30), 3) #longitude ranges from -30 to 30
    lat = round(uniform(-90, 90), 3) #latitude ranges from -90 to 90
 #feed into citipy the lat, long coordinates to return as city object    
    city = citipy.nearest_city(lat, long)
    city_name = city.city_name
    country_code = city.country_code

    city_entry = f"{city_name},{country_code}"
    if city_entry not in cities:
        cities.append(city_entry)
        print(f"city: {city_entry}")
        #establishing a base URL
        #url = used above to test connection
         #api.openweathermap.org/data/2.5/weather?q=London,uk&APPID=ed8107ba19974709385b0b4cb54184ff - example of what the call should look like..
        city_request = url + f"{city}"
        query_url = url + "APPID=" + w_api  + "&q=" + city_entry + "?" + "&units=metric"
        print(f"Request for {city_request}")
       
        
        response = requests.get(query_url)
        weather_json = response.json()
        print("weather data: \n")
        pprint(weather_json)
        if weather_json['cod'] == 200:
            weather.append(weather_json)
        elif weather_json['cod'] == 404:
            weatherless_cities.append(city_entry)
        else:
            pass
    else:
        print(f"duplicate city: {city_entry}")
        dup_cities.append(city_entry)
# Out:
# city: mirina,gr
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0695AAA8>
# weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city: marck,fr
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x068AF9A0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 50.95, 'lon': 1.94},
#  'dt': 1603236063,
#  'id': 2995938,
#  'main': {'feels_like': 14.98,
#           'humidity': 91,
#           'pressure': 1002,
#           'temp': 14.62,
#           'temp_max': 15,
#           'temp_min': 14.44},
#  'name': 'Marck',
#  'sys': {'country': 'FR',
#          'id': 2008203,
#          'sunrise': 1603261550,
#          'sunset': 1603298848,
#          'type': 3},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 144, 'gust': 3.58, 'speed': 0.89}}
# city: abu zabad,sd
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x07219760>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 12.35, 'lon': 29.25},
#  'dt': 1603236063,
#  'id': 380348,
#  'main': {'feels_like': 26.53,
#           'grnd_level': 947,
#           'humidity': 32,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 27.79,
#           'temp_max': 27.79,
#           'temp_min': 27.79},
#  'name': 'Abū Zabad',
#  'sys': {'country': 'SD', 'sunrise': 1603252414, 'sunset': 1603294877},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 7, 'speed': 1.7}}
# city: sindou,bf
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06594E08>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 85},
#  'cod': 200,
#  'coord': {'lat': 10.67, 'lon': -5.17},
#  'dt': 1603236064,
#  'id': 2355548,
#  'main': {'feels_like': 26.41,
#           'grnd_level': 970,
#           'humidity': 74,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 23.87,
#           'temp_max': 23.87,
#           'temp_min': 23.87},
#  'name': 'Sindou',
#  'sys': {'country': 'BF', 'sunrise': 1603174189, 'sunset': 1603216840},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 61, 'speed': 0.95}}
# city: arraial do cabo,br
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x065BCE98>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': -22.97, 'lon': -42.03},
#  'dt': 1603235832,
#  'id': 3471451,
#  'main': {'feels_like': 19.35,
#           'grnd_level': 1015,
#           'humidity': 82,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 22.81,
#           'temp_max': 22.81,
#           'temp_min': 22.81},
#  'name': 'Arraial do Cabo',
#  'sys': {'country': 'BR', 'sunrise': 1603181453, 'sunset': 1603227267},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 57, 'speed': 9.93}}
# city: hermanus,za
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06C911F0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.23},
#  'dt': 1603236064,
#  'id': 3366880,
#  'main': {'feels_like': 4.95,
#           'humidity': 92,
#           'pressure': 1024,
#           'temp': 7.22,
#           'temp_max': 7.22,
#           'temp_min': 7.22},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'sunrise': 1603252392,
#          'sunset': 1603299707,
#          'type': 3},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 39, 'speed': 1.93}}
# city: buta,cd
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0669AB50>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 94},
#  'cod': 200,
#  'coord': {'lat': 2.79, 'lon': 24.73},
#  'dt': 1603236064,
#  'id': 217570,
#  'main': {'feels_like': 25.34,
#           'grnd_level': 964,
#           'humidity': 98,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 21.53,
#           'temp_max': 21.53,
#           'temp_min': 21.53},
#  'name': 'Buta',
#  'rain': {'1h': 0.69},
#  'sys': {'country': 'CD', 'sunrise': 1603253055, 'sunset': 1603296405},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 125, 'speed': 0.68}}
# city: waddan,ly
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06CE46D0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 29.16, 'lon': 16.14},
#  'dt': 1603236064,
#  'id': 2209055,
#  'main': {'feels_like': 14.4,
#           'grnd_level': 993,
#           'humidity': 72,
#           'pressure': 1023,
#           'sea_level': 1023,
#           'temp': 17.34,
#           'temp_max': 17.34,
#           'temp_min': 17.34},
#  'name': 'Waddān',
#  'sys': {'country': 'LY', 'sunrise': 1603256430, 'sunset': 1603297153},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 66, 'speed': 5.19}}
# duplicate city: hermanus,za
# city: keuruu,fi
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06882D30>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 62.27, 'lon': 24.7},
#  'dt': 1603236065,
#  'id': 652977,
#  'main': {'feels_like': -4.9,
#           'humidity': 86,
#           'pressure': 1015,
#           'temp': -1.04,
#           'temp_max': -1,
#           'temp_min': -1.11},
#  'name': 'Keuruu',
#  'sys': {'country': 'FI',
#          'id': 1333,
#          'sunrise': 1603257795,
#          'sunset': 1603291680,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'speed': 2.1}}
# city: camacha,pt
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06FA4FE8>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 33.08, 'lon': -16.33},
#  'dt': 1603236065,
#  'id': 2270385,
#  'main': {'feels_like': 15.84,
#           'humidity': 68,
#           'pressure': 1012,
#           'temp': 20,
#           'temp_max': 20,
#           'temp_min': 20},
#  'name': 'Camacha',
#  'sys': {'country': 'PT',
#          'id': 6902,
#          'sunrise': 1603264465,
#          'sunset': 1603304702,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 280, 'speed': 7.7}}
# city: jamestown,sh
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x07227370>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 42.1, 'lon': -79.24},
#  'dt': 1603236022,
#  'id': 5122534,
#  'main': {'feels_like': 4.92,
#           'humidity': 93,
#           'pressure': 1024,
#           'temp': 8.41,
#           'temp_max': 8.89,
#           'temp_min': 8},
#  'name': 'Jamestown',
#  'sys': {'country': 'US',
#          'id': 4588,
#          'sunrise': 1603193744,
#          'sunset': 1603232835,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 4.1}}
# city: longyearbyen,sj
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x07230268>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 78.22, 'lon': 15.64},
#  'dt': 1603235843,
#  'id': 2729907,
#  'main': {'feels_like': -10.42,
#           'humidity': 79,
#           'pressure': 1025,
#           'temp': -5,
#           'temp_max': -5,
#           'temp_min': -5},
#  'name': 'Longyearbyen',
#  'sys': {'country': 'SJ',
#          'id': 1663,
#          'sunrise': 1603269178,
#          'sunset': 1603284644,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 130, 'speed': 3.6}}
# city: lagoa,pt
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06FADA18>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 58},
#  'cod': 200,
#  'coord': {'lat': 39.05, 'lon': -27.98},
#  'dt': 1603236066,
#  'id': 3372964,
#  'main': {'feels_like': 9.1,
#           'grnd_level': 1014,
#           'humidity': 66,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 17.35,
#           'temp_max': 17.35,
#           'temp_min': 17.35},
#  'name': 'Lagoa',
#  'rain': {'1h': 0.12},
#  'sys': {'country': 'PT', 'sunrise': 1603181206, 'sunset': 1603220771},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 352, 'speed': 12.22}}
# city: matay,eg
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0684F9B8>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 28.42, 'lon': 30.78},
#  'dt': 1603235918,
#  'id': 352628,
#  'main': {'feels_like': 19.96,
#           'grnd_level': 1011,
#           'humidity': 52,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 22.97,
#           'temp_max': 22.97,
#           'temp_min': 22.97},
#  'name': 'Maţāy',
#  'sys': {'country': 'EG', 'sunrise': 1603252872, 'sunset': 1603293684},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 359, 'speed': 5.44}}
# duplicate city: longyearbyen,sj
# city: bredasdorp,za
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06C8C490>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34.53, 'lon': 20.04},
#  'dt': 1603236018,
#  'id': 1015776,
#  'main': {'feels_like': 3.21,
#           'humidity': 87,
#           'pressure': 1023,
#           'temp': 6,
#           'temp_max': 6,
#           'temp_min': 6},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 1966,
#          'sunrise': 1603252190,
#          'sunset': 1603299521,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 60, 'speed': 2.1}}
# city: wamba,cd
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0669F9D0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 11},
#  'cod': 200,
#  'coord': {'lat': 8.93, 'lon': 8.6},
#  'dt': 1603236066,
#  'id': 2319257,
#  'main': {'feels_like': 26.15,
#           'grnd_level': 972,
#           'humidity': 81,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 23.34,
#           'temp_max': 23.34,
#           'temp_min': 23.34},
#  'name': 'Wamba',
#  'sys': {'country': 'NG', 'sunrise': 1603257209, 'sunset': 1603299992},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 333, 'speed': 1.19}}
# city: abonnema,ng
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DABF58>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 4.71, 'lon': 6.79},
#  'dt': 1603236067,
#  'id': 2324433,
#  'main': {'feels_like': 26.92,
#           'humidity': 94,
#           'pressure': 1013,
#           'temp': 24,
#           'temp_max': 24,
#           'temp_min': 24},
#  'name': 'Abonnema',
#  'sys': {'country': 'NG',
#          'id': 1170,
#          'sunrise': 1603257449,
#          'sunset': 1603300622,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 7000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 263, 'speed': 3.3}}
# city: ushuaia,ar
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0652C1F0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -54.8, 'lon': -68.3},
#  'dt': 1603236067,
#  'id': 3833367,
#  'main': {'feels_like': 2.2,
#           'humidity': 77,
#           'pressure': 1020,
#           'temp': 6,
#           'temp_max': 6,
#           'temp_min': 6},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1603185018,
#          'sunset': 1603236311,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 3.1}}
# city: georgetown,sh
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x07227328>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 5.41, 'lon': 100.34},
#  'dt': 1603235861,
#  'id': 1735106,
#  'main': {'feels_like': 30.69,
#           'humidity': 88,
#           'pressure': 1009,
#           'temp': 25.78,
#           'temp_max': 26,
#           'temp_min': 25.56},
#  'name': 'George Town',
#  'sys': {'country': 'MY',
#          'id': 9429,
#          'sunrise': 1603235029,
#          'sunset': 1603278142,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 8000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 1}}
# city: hofn,is
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06B3DDC0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 64.25, 'lon': -15.21},
#  'dt': 1603235836,
#  'id': 2630299,
#  'main': {'feels_like': -2.59,
#           'grnd_level': 1016,
#           'humidity': 76,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 2.32,
#           'temp_max': 2.32,
#           'temp_min': 2.32},
#  'name': 'Hofn',
#  'sys': {'country': 'IS', 'sunrise': 1603181254, 'sunset': 1603214594},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 3.89}}
# city: nalut,ly
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06CE4400>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 3},
#  'cod': 200,
#  'coord': {'lat': 30.33, 'lon': 10.85},
#  'dt': 1603236068,
#  'id': 2214432,
#  'main': {'feels_like': 9.83,
#           'grnd_level': 962,
#           'humidity': 37,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': 16.52,
#           'temp_max': 16.52,
#           'temp_min': 16.52},
#  'name': 'Nālūt',
#  'sys': {'country': 'LY', 'sunrise': 1603257769, 'sunset': 1603298353},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 105, 'speed': 7.12}}
# duplicate city: jamestown,sh
# city: cape town,za
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06C8C6D0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1603235897,
#  'id': 3369157,
#  'main': {'feels_like': 9.35,
#           'humidity': 81,
#           'pressure': 1023,
#           'temp': 10.92,
#           'temp_max': 11.67,
#           'temp_min': 10},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 1899,
#          'sunrise': 1603252621,
#          'sunset': 1603299867,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 200, 'speed': 1.5}}
# city: luderitz,na
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DA6598>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -26.65, 'lon': 15.16},
#  'dt': 1603236027,
#  'id': 3355672,
#  'main': {'feels_like': 9.9,
#           'grnd_level': 1009,
#           'humidity': 46,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 17.89,
#           'temp_max': 17.89,
#           'temp_min': 17.89},
#  'name': 'Lüderitz',
#  'sys': {'country': 'NA', 'sunrise': 1603253875, 'sunset': 1603300178},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 166, 'speed': 10.13}}
# duplicate city: jamestown,sh
# duplicate city: georgetown,sh
# city: husavik,is
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06B3DE08>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 79},
#  'cod': 200,
#  'coord': {'lat': 66.04, 'lon': -17.34},
#  'dt': 1603235962,
#  'id': 2629833,
#  'main': {'feels_like': -8.2,
#           'humidity': 85,
#           'pressure': 1015,
#           'temp': -4,
#           'temp_max': -4,
#           'temp_min': -4},
#  'name': 'Husavik',
#  'sys': {'country': 'IS',
#          'id': 83,
#          'sunrise': 1603182217,
#          'sunset': 1603214653,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 2.1}}
# duplicate city: cape town,za
# duplicate city: arraial do cabo,br
# duplicate city: hofn,is
# city: oksfjord,no
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DEA958>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 70.24, 'lon': 22.35},
#  'dt': 1603236068,
#  'id': 778362,
#  'main': {'feels_like': -7.51,
#           'humidity': 92,
#           'pressure': 1018,
#           'temp': -2.84,
#           'temp_max': -2,
#           'temp_min': -3},
#  'name': 'Øksfjord',
#  'sys': {'country': 'NO',
#          'id': 1606,
#          'sunrise': 1603260729,
#          'sunset': 1603289873,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 3.1}}
# city: vila velha,br
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06652CD0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -20.33, 'lon': -40.29},
#  'dt': 1603235983,
#  'id': 3445026,
#  'main': {'feels_like': 22.52,
#           'humidity': 94,
#           'pressure': 1018,
#           'temp': 21,
#           'temp_max': 21,
#           'temp_min': 21},
#  'name': 'Vila Velha',
#  'rain': {'1h': 2.73},
#  'sys': {'country': 'BR',
#          'id': 8474,
#          'sunrise': 1603181177,
#          'sunset': 1603226708,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 50, 'speed': 3.1}}
# city: podor,sn
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x07241208>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 11},
#  'cod': 200,
#  'coord': {'lat': 16.65, 'lon': -14.96},
#  'dt': 1603236069,
#  'id': 2245170,
#  'main': {'feels_like': 30.3,
#           'humidity': 38,
#           'pressure': 1015,
#           'temp': 31,
#           'temp_max': 31,
#           'temp_min': 31},
#  'name': 'Podor',
#  'sys': {'country': 'MR',
#          'id': 2427,
#          'sunrise': 1603176816,
#          'sunset': 1603218912,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 3.31}}
# duplicate city: longyearbyen,sj
# city: tukrah,ly
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06CE4688>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 14},
#  'cod': 200,
#  'coord': {'lat': 32.53, 'lon': 20.58},
#  'dt': 1603236069,
#  'id': 88834,
#  'main': {'feels_like': 18.48,
#           'grnd_level': 1019,
#           'humidity': 67,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': 19.82,
#           'temp_max': 19.82,
#           'temp_min': 19.82},
#  'name': 'Tūkrah',
#  'sys': {'country': 'LY', 'sunrise': 1603255567, 'sunset': 1603295885},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 22, 'speed': 3.48}}
# city: raudeberg,no
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DEAD90>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 61.99, 'lon': 5.14},
#  'dt': 1603236069,
#  'id': 3146487,
#  'main': {'feels_like': 2.34,
#           'humidity': 94,
#           'pressure': 997,
#           'temp': 6.67,
#           'temp_max': 6.67,
#           'temp_min': 6.67},
#  'name': 'Raudeberg',
#  'rain': {'1h': 0.13},
#  'sys': {'country': 'NO',
#          'id': 2003008,
#          'sunrise': 1603262440,
#          'sunset': 1603296422,
#          'type': 3},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 65, 'speed': 4.8}}
# city: pravdinsk,ru
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0719A310>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 54.44, 'lon': 21.02},
#  'dt': 1603236070,
#  'id': 505599,
#  'main': {'feels_like': 4.89,
#           'humidity': 87,
#           'pressure': 1013,
#           'temp': 7.93,
#           'temp_max': 8,
#           'temp_min': 7.78},
#  'name': 'Pravdinsk',
#  'rain': {'1h': 0.21},
#  'sys': {'country': 'RU',
#          'id': 8934,
#          'sunrise': 1603257387,
#          'sunset': 1603293854,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 160, 'speed': 3}}
# duplicate city: hermanus,za
# city: illoqqortoormiut,gl
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06920DD8>
# weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city: agadir,ma
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06CE4838>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 30.42, 'lon': -9.6},
#  'dt': 1603236070,
#  'id': 2561668,
#  'main': {'feels_like': 23.3,
#           'humidity': 73,
#           'pressure': 1015,
#           'temp': 22,
#           'temp_max': 22,
#           'temp_min': 22},
#  'name': 'Santa Cruz',
#  'rain': {'1h': 0.38},
#  'sys': {'country': 'MA',
#          'id': 2393,
#          'sunrise': 1603262685,
#          'sunset': 1603303252,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 110, 'speed': 1.5}}
# city: barentsburg,sj
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x07230220>
# weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city: oranjemund,na
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DA6868>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -28.55, 'lon': 16.43},
#  'dt': 1603236070,
#  'id': 3354071,
#  'main': {'feels_like': 8.34,
#           'grnd_level': 1013,
#           'humidity': 72,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 14.7,
#           'temp_max': 14.7,
#           'temp_min': 14.7},
#  'name': 'Oranjemund',
#  'sys': {'country': 'NA', 'sunrise': 1603253454, 'sunset': 1603299989},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 150, 'speed': 9.04}}
# city: sorvag,fo
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0688A2B0>
# weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: longyearbyen,sj
# city: kraste,al
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0650C4C0>
# weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city: saldanha,za
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06C95610>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.01, 'lon': 17.94},
#  'dt': 1603235953,
#  'id': 3361934,
#  'main': {'feels_like': 5.81,
#           'humidity': 81,
#           'pressure': 1022,
#           'temp': 8,
#           'temp_max': 8,
#           'temp_min': 8},
#  'name': 'Saldanha',
#  'sys': {'country': 'ZA',
#          'id': 1943,
#          'sunrise': 1603252801,
#          'sunset': 1603299918,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 170, 'speed': 1.5}}
# city: grindavik,is
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06B3DD30>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 63.84, 'lon': -22.43},
#  'dt': 1603236071,
#  'id': 3416888,
#  'main': {'feels_like': -0.67,
#           'humidity': 86,
#           'pressure': 1015,
#           'temp': 3,
#           'temp_max': 3,
#           'temp_min': 3},
#  'name': 'Grindavik',
#  'sys': {'country': 'IS',
#          'id': 90,
#          'sunrise': 1603182896,
#          'sunset': 1603216417,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'shower rain',
#               'icon': '09n',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 220, 'speed': 2.6}}
# city: sarh,td
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x07254310>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 9.14, 'lon': 18.39},
#  'dt': 1603236071,
#  'id': 2425791,
#  'main': {'feels_like': 31.54,
#           'humidity': 88,
#           'pressure': 1010,
#           'temp': 26,
#           'temp_max': 26,
#           'temp_min': 26},
#  'name': 'Sarh',
#  'sys': {'country': 'TD',
#          'id': 2216,
#          'sunrise': 1603254870,
#          'sunset': 1603297633,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 149, 'speed': 0.27}}
# duplicate city: hofn,is
# city: sao joao da barra,br
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0663C8F8>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': -21.64, 'lon': -41.05},
#  'dt': 1603235952,
#  'id': 3448903,
#  'main': {'feels_like': 22.44,
#           'grnd_level': 1016,
#           'humidity': 82,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 22.61,
#           'temp_max': 22.61,
#           'temp_min': 22.61},
#  'name': 'São João da Barra',
#  'rain': {'1h': 0.20179999999999998},
#  'sys': {'country': 'BR', 'sunrise': 1603181290, 'sunset': 1603226960},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 53, 'speed': 5.1}}
# city: tawzar,tn
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x07273628>
# weather data:
#
# {'cod': '404', 'message': 'city not found'}
# city: arlit,ne
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DAB580>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 18.74, 'lon': 7.39},
#  'dt': 1603236072,
#  'id': 2447513,
#  'main': {'feels_like': 26.26,
#           'grnd_level': 966,
#           'humidity': 12,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 30.82,
#           'temp_max': 30.82,
#           'temp_min': 30.82},
#  'name': 'Arlit',
#  'sys': {'country': 'NE', 'sunrise': 1603257971, 'sunset': 1603299811},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 128, 'speed': 3.31}}
# duplicate city: cape town,za
# city: alexandria,eg
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0684F268>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 31.22, 'lon': 29.96},
#  'dt': 1603236072,
#  'id': 361058,
#  'main': {'feels_like': 26.26,
#           'humidity': 78,
#           'pressure': 1017,
#           'temp': 25,
#           'temp_max': 25,
#           'temp_min': 25},
#  'name': 'Alexandria',
#  'sys': {'country': 'EG',
#          'id': 2511,
#          'sunrise': 1603253234,
#          'sunset': 1603293716,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 40, 'speed': 4.1}}
# city: olafsvik,is
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06B3DF70>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 64.89, 'lon': -23.71},
#  'dt': 1603236073,
#  'id': 3414079,
#  'main': {'feels_like': 0.68,
#           'grnd_level': 1010,
#           'humidity': 82,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 6.01,
#           'temp_max': 6.01,
#           'temp_min': 6.01},
#  'name': 'Olafsvik',
#  'rain': {'1h': 0.4},
#  'sys': {'country': 'IS', 'sunrise': 1603183452, 'sunset': 1603216475},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 248, 'speed': 5.51}}
# city: sao filipe,cv
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0676E820>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 14.9, 'lon': -24.5},
#  'dt': 1603236073,
#  'id': 3374210,
#  'main': {'feels_like': 30.94,
#           'grnd_level': 1009,
#           'humidity': 61,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 29.11,
#           'temp_max': 29.11,
#           'temp_min': 29.11},
#  'name': 'São Filipe',
#  'sys': {'country': 'CV', 'sunrise': 1603179024, 'sunset': 1603221283},
#  'timezone': -3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 105, 'speed': 3.23}}
# duplicate city: cape town,za
# duplicate city: grindavik,is
# city: moussoro,td
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x072541F0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 13.64, 'lon': 16.49},
#  'dt': 1603236073,
#  'id': 2427336,
#  'main': {'feels_like': 26.47,
#           'grnd_level': 977,
#           'humidity': 13,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 30.95,
#           'temp_max': 30.95,
#           'temp_min': 30.95},
#  'name': 'Moussoro',
#  'sys': {'country': 'TD', 'sunrise': 1603255538, 'sunset': 1603297877},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 39, 'speed': 3.42}}
# city: soyo,ao
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06523BB0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 89},
#  'cod': 200,
#  'coord': {'lat': -6.13, 'lon': 12.37},
#  'dt': 1603236073,
#  'id': 2236967,
#  'main': {'feels_like': 27.29,
#           'grnd_level': 1012,
#           'humidity': 83,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 24.87,
#           'temp_max': 24.87,
#           'temp_min': 24.87},
#  'name': 'Soyo',
#  'sys': {'country': 'AO', 'sunrise': 1603255609, 'sunset': 1603299783},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 254, 'speed': 3.09}}
# duplicate city: hermanus,za
# city: honningsvag,no
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DE1A60>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 74},
#  'cod': 200,
#  'coord': {'lat': 70.98, 'lon': 25.97},
#  'dt': 1603236073,
#  'id': 779554,
#  'main': {'feels_like': -0.28,
#           'grnd_level': 1016,
#           'humidity': 72,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 3.93,
#           'temp_max': 3.93,
#           'temp_min': 3.93},
#  'name': 'Honningsvåg',
#  'sys': {'country': 'NO', 'sunrise': 1603260187, 'sunset': 1603288678},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 123, 'speed': 3.05}}
# city: namibe,ao
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06523AD8>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 60},
#  'cod': 200,
#  'coord': {'lat': -15.2, 'lon': 12.15},
#  'dt': 1603236074,
#  'id': 3347019,
#  'main': {'feels_like': 19.77,
#           'grnd_level': 1008,
#           'humidity': 84,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 19.36,
#           'temp_max': 19.36,
#           'temp_min': 19.36},
#  'name': 'Mossamedes',
#  'sys': {'country': 'AO', 'sunrise': 1603255222, 'sunset': 1603300276},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 255, 'speed': 2.57}}
# city: siniscola,it
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06B8D370>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 40.57, 'lon': 9.69},
#  'dt': 1603236074,
#  'id': 3166509,
#  'main': {'feels_like': 8.29,
#           'humidity': 93,
#           'pressure': 1022,
#           'temp': 10,
#           'temp_max': 10,
#           'temp_min': 10},
#  'name': 'Siniscola',
#  'sys': {'country': 'IT',
#          'id': 6728,
#          'sunrise': 1603258735,
#          'sunset': 1603297943,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 240, 'speed': 2.1}}
# city: klaksvik,fo
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0688A0E8>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 19},
#  'cod': 200,
#  'coord': {'lat': 62.23, 'lon': -6.59},
#  'dt': 1603236060,
#  'id': 2618795,
#  'main': {'feels_like': 0.06,
#           'humidity': 70,
#           'pressure': 1007,
#           'temp': 4,
#           'temp_max': 4,
#           'temp_min': 4},
#  'name': 'Klaksvík',
#  'sys': {'country': 'FO',
#          'id': 1596,
#          'sunrise': 1603265311,
#          'sunset': 1603299181,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 2.6}}
# city: teguise,es
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06874790>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 29.06, 'lon': -13.56},
#  'dt': 1603235967,
#  'id': 2510573,
#  'main': {'feels_like': 24.6,
#           'humidity': 69,
#           'pressure': 1015,
#           'temp': 24,
#           'temp_max': 24,
#           'temp_min': 24},
#  'name': 'Teguise',
#  'sys': {'country': 'ES',
#          'id': 2379,
#          'sunrise': 1603263555,
#          'sunset': 1603304282,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 310, 'speed': 3.1}}
# city: kruisfontein,za
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06C91700>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34, 'lon': 24.73},
#  'dt': 1603235989,
#  'id': 986717,
#  'main': {'feels_like': 9.73,
#           'humidity': 83,
#           'pressure': 1024,
#           'temp': 11.67,
#           'temp_max': 11.67,
#           'temp_min': 11.67},
#  'name': 'Kruisfontein',
#  'sys': {'country': 'ZA',
#          'id': 2035063,
#          'sunrise': 1603251103,
#          'sunset': 1603298357,
#          'type': 3},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 334, 'speed': 2.42}}
# duplicate city: cape town,za
# city: adrar,dz
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06835C10>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 20.5, 'lon': -10.07},
#  'dt': 1603235970,
#  'id': 2381972,
#  'main': {'feels_like': 25.65,
#           'grnd_level': 971,
#           'humidity': 15,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 29.66,
#           'temp_max': 29.66,
#           'temp_min': 29.66},
#  'name': 'Adrar',
#  'sys': {'country': 'MR', 'sunrise': 1603175828, 'sunset': 1603217553},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 53, 'speed': 2.95}}
# duplicate city: hermanus,za
# duplicate city: jamestown,sh
# city: sapele,ng
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DB9460>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 78},
#  'cod': 200,
#  'coord': {'lat': 5.89, 'lon': 5.68},
#  'dt': 1603236075,
#  'id': 2323675,
#  'main': {'feels_like': 29.09,
#           'grnd_level': 1012,
#           'humidity': 95,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 24.39,
#           'temp_max': 24.39,
#           'temp_min': 24.39},
#  'name': 'Sapele',
#  'sys': {'country': 'NG', 'sunrise': 1603257769, 'sunset': 1603300834},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 238, 'speed': 1.21}}
# duplicate city: sao filipe,cv
# duplicate city: hermanus,za
# duplicate city: luderitz,na
# city: nioro,ml
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06CFB130>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 82},
#  'cod': 200,
#  'coord': {'lat': 13.35, 'lon': -15.75},
#  'dt': 1603236075,
#  'id': 2412408,
#  'main': {'feels_like': 29.5,
#           'grnd_level': 1008,
#           'humidity': 89,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 25.89,
#           'temp_max': 25.89,
#           'temp_min': 25.89},
#  'name': 'Nioro',
#  'sys': {'country': 'GM', 'sunrise': 1603176851, 'sunset': 1603219256},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 256, 'speed': 3.1}}
# city: pulsano,it
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06B811A8>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 40.38, 'lon': 17.36},
#  'dt': 1603236076,
#  'id': 3169760,
#  'main': {'feels_like': 13.39,
#           'humidity': 78,
#           'pressure': 1021,
#           'temp': 13.93,
#           'temp_max': 15.56,
#           'temp_min': 10.56},
#  'name': 'Pulsano',
#  'sys': {'country': 'IT',
#          'id': 2001835,
#          'sunrise': 1603256878,
#          'sunset': 1603296119,
#          'type': 3},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 303, 'gust': 1.34, 'speed': 0.89}}
# duplicate city: hermanus,za
# city: george,za
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06C8CE68>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': -33.96, 'lon': 22.46},
#  'dt': 1603236076,
#  'id': 1002145,
#  'main': {'feels_like': 11.67,
#           'humidity': 87,
#           'pressure': 1023,
#           'temp': 12,
#           'temp_max': 12,
#           'temp_min': 12},
#  'name': 'George',
#  'sys': {'country': 'ZA',
#          'id': 1918,
#          'sunrise': 1603251650,
#          'sunset': 1603298899,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 0.5}}
# city: los llanos de aridane,es
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06867868>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 49},
#  'cod': 200,
#  'coord': {'lat': 28.66, 'lon': -17.92},
#  'dt': 1603236076,
#  'id': 2514651,
#  'main': {'feels_like': 15.29,
#           'humidity': 50,
#           'pressure': 1015,
#           'temp': 19.2,
#           'temp_max': 24,
#           'temp_min': 16.11},
#  'name': 'Los Llanos de Aridane',
#  'sys': {'country': 'ES',
#          'id': 2377,
#          'sunrise': 1603264579,
#          'sunset': 1603305351,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 5.1}}
# duplicate city: illoqqortoormiut,gl
# duplicate city: illoqqortoormiut,gl
# city: binga,cd
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0669A7A8>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -17.62, 'lon': 27.34},
#  'dt': 1603236076,
#  'id': 895057,
#  'main': {'feels_like': 22.24,
#           'grnd_level': 940,
#           'humidity': 27,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 25.06,
#           'temp_max': 25.06,
#           'temp_min': 25.06},
#  'name': 'Binga',
#  'sys': {'country': 'ZW', 'sunrise': 1603251454, 'sunset': 1603296753},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 40, 'speed': 2.35}}
# duplicate city: illoqqortoormiut,gl
# duplicate city: hermanus,za
# duplicate city: illoqqortoormiut,gl
# city: saint-louis,sn
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x072412E0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 16},
#  'cod': 200,
#  'coord': {'lat': 16.33, 'lon': -15},
#  'dt': 1603236077,
#  'id': 2246451,
#  'main': {'feels_like': 29.93,
#           'humidity': 38,
#           'pressure': 1015,
#           'temp': 31,
#           'temp_max': 31,
#           'temp_min': 31},
#  'name': 'Saint-Louis',
#  'sys': {'country': 'SN',
#          'id': 2427,
#          'sunrise': 1603176810,
#          'sunset': 1603218937,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 42, 'speed': 3.84}}
# city: westport,ie
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06A36970>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 34},
#  'cod': 200,
#  'coord': {'lat': 41.14, 'lon': -73.36},
#  'dt': 1603235825,
#  'id': 4845585,
#  'main': {'feels_like': 16.93,
#           'humidity': 96,
#           'pressure': 1023,
#           'temp': 16.43,
#           'temp_max': 17.22,
#           'temp_min': 15.56},
#  'name': 'Westport',
#  'sys': {'country': 'US',
#          'id': 2011298,
#          'sunrise': 1603192258,
#          'sunset': 1603231499,
#          'type': 3},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 114, 'speed': 2.01}}
# duplicate city: hofn,is
# duplicate city: cape town,za
# city: muros,es
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0686B6A0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 42.78, 'lon': -9.06},
#  'dt': 1603236066,
#  'id': 3115824,
#  'main': {'feels_like': 11.38,
#           'humidity': 91,
#           'pressure': 995,
#           'temp': 14.5,
#           'temp_max': 15,
#           'temp_min': 13.89},
#  'name': 'Muros',
#  'rain': {'1h': 0.83},
#  'sys': {'country': 'ES',
#          'id': 72671,
#          'sunrise': 1603263414,
#          'sunset': 1603302264,
#          'type': 3},
#  'timezone': 7200,
#  'visibility': 6208,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 165, 'gust': 10.73, 'speed': 5.81}}
# duplicate city: adrar,dz
# city: maiduguri,ng
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DB4988>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 22},
#  'cod': 200,
#  'coord': {'lat': 11.85, 'lon': 13.16},
#  'dt': 1603236077,
#  'id': 2331447,
#  'main': {'feels_like': 25.2,
#           'grnd_level': 974,
#           'humidity': 24,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 26.74,
#           'temp_max': 26.74,
#           'temp_min': 26.74},
#  'name': 'Maiduguri',
# ...
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06F9FCE8>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 14},
#  'cod': 200,
#  'coord': {'lat': 37.32, 'lon': -8.8},
#  'dt': 1603236183,
#  'id': 2271968,
#  'main': {'feels_like': 16.33,
#           'humidity': 96,
#           'pressure': 1005,
#           'temp': 16.11,
#           'temp_max': 16.11,
#           'temp_min': 16.11},
#  'name': 'Aljezur',
#  'rain': {'1h': 0.23},
#  'sys': {'country': 'PT',
#          'id': 73730,
#          'sunrise': 1603262938,
#          'sunset': 1603302615,
#          'type': 3},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 205, 'gust': 2.68, 'speed': 2.24}}
# duplicate city: east london,za
# duplicate city: bonthe,sl
# duplicate city: port elizabeth,za
# duplicate city: chuy,uy
# duplicate city: hermanus,za
# duplicate city: arraial do cabo,br
# duplicate city: hermanus,za
# duplicate city: barentsburg,sj
# duplicate city: cape town,za
# duplicate city: barentsburg,sj
# duplicate city: ondjiva,ao
# duplicate city: vestmannaeyjar,is
# duplicate city: arraial do cabo,br
# city: sinazongwe,zm
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06C9E940>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -17.26, 'lon': 27.46},
#  'dt': 1603236184,
#  'id': 897456,
#  'main': {'feels_like': 23.98,
#           'grnd_level': 955,
#           'humidity': 29,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 26.25,
#           'temp_max': 26.25,
#           'temp_min': 26.25},
#  'name': 'Sinazongwe',
#  'sys': {'country': 'ZM', 'sunrise': 1603251444, 'sunset': 1603296706},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 20, 'speed': 2.18}}
# duplicate city: jamestown,sh
# duplicate city: faya,td
# duplicate city: luderitz,na
# duplicate city: sao joao da barra,br
# duplicate city: cape town,za
# city: vigrestad,no
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DF73B8>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 96},
#  'cod': 200,
#  'coord': {'lat': 58.57, 'lon': 5.7},
#  'dt': 1603236184,
#  'id': 3131824,
#  'main': {'feels_like': 9.78,
#           'humidity': 99,
#           'pressure': 989,
#           'temp': 10.56,
#           'temp_max': 10.56,
#           'temp_min': 10.56},
#  'name': 'Vigrestad',
#  'sys': {'country': 'NO',
#          'id': 2034752,
#          'sunrise': 1603261676,
#          'sunset': 1603296918,
#          'type': 3},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'gust': 1.34, 'speed': 1.34}}
# duplicate city: illoqqortoormiut,gl
# duplicate city: hermanus,za
# duplicate city: cape town,za
# duplicate city: jamestown,sh
# duplicate city: cape town,za
# duplicate city: hermanus,za
# duplicate city: praia da vitoria,pt
# city: nola,cf
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x066A3418>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 47},
#  'cod': 200,
#  'coord': {'lat': 40.92, 'lon': 14.53},
#  'dt': 1603236184,
#  'id': 6541905,
#  'main': {'feels_like': 11.55,
#           'humidity': 81,
#           'pressure': 1025,
#           'temp': 12.41,
#           'temp_max': 15,
#           'temp_min': 11},
#  'name': 'Nola',
#  'sys': {'country': 'IT',
#          'id': 6802,
#          'sunrise': 1603257599,
#          'sunset': 1603296756,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 1}}
# duplicate city: cape town,za
# duplicate city: cape town,za
# duplicate city: walvis bay,na
# duplicate city: jamestown,sh
# duplicate city: illoqqortoormiut,gl
# duplicate city: dingle,ie
# duplicate city: jamestown,sh
# duplicate city: praia,cv
# duplicate city: arlit,ne
# duplicate city: illoqqortoormiut,gl
# duplicate city: port elizabeth,za
# duplicate city: sao joao da barra,br
# duplicate city: bredasdorp,za
# duplicate city: oussouye,sn
# city: matameye,ne
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DABAD8>
# weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: cape town,za
# duplicate city: cape town,za
# duplicate city: sorland,no
# duplicate city: jalu,ly
# duplicate city: ayorou,ne
# duplicate city: bonthe,sl
# duplicate city: klaksvik,fo
# duplicate city: sistranda,no
# duplicate city: takoradi,gh
# city: navahrudak,by
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0665F418>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 53.6, 'lon': 25.83},
#  'dt': 1603236185,
#  'id': 624785,
#  'main': {'feels_like': 0.46,
#           'grnd_level': 985,
#           'humidity': 84,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': 4.9,
#           'temp_max': 4.9,
#           'temp_min': 4.9},
#  'name': 'Navahrudak',
#  'sys': {'country': 'BY', 'sunrise': 1603256123, 'sunset': 1603292809},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 178, 'speed': 4.06}}
# duplicate city: tukrah,ly
# duplicate city: longyearbyen,sj
# city: castleblayney,ie
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06A2D958>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 54.12, 'lon': -6.73},
#  'dt': 1603236185,
#  'id': 2965649,
#  'main': {'feels_like': 9.59,
#           'humidity': 81,
#           'pressure': 989,
#           'temp': 12.78,
#           'temp_max': 12.78,
#           'temp_min': 12.78},
#  'name': 'Castleblayney',
#  'rain': {'1h': 0.29},
#  'sys': {'country': 'IE',
#          'id': 2010234,
#          'sunrise': 1603264014,
#          'sunset': 1603300545,
#          'type': 3},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 198, 'gust': 8.49, 'speed': 4.47}}
# duplicate city: bredasdorp,za
# duplicate city: illoqqortoormiut,gl
# duplicate city: jamestown,sh
# duplicate city: cape town,za
# city: alferrarede,pt
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06F9FB80>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 85},
#  'cod': 200,
#  'coord': {'lat': 39.48, 'lon': -8.17},
#  'dt': 1603236185,
#  'id': 2272010,
#  'main': {'feels_like': 14.71,
#           'humidity': 94,
#           'pressure': 1000,
#           'temp': 14.53,
#           'temp_max': 15,
#           'temp_min': 13.33},
#  'name': 'Alferrarede',
#  'rain': {'1h': 0.18},
#  'sys': {'country': 'PT',
#          'id': 2001942,
#          'sunrise': 1603262943,
#          'sunset': 1603302308,
#          'type': 3},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 186, 'gust': 5.36, 'speed': 1.34}}
# duplicate city: husavik,is
# duplicate city: barentsburg,sj
# city: kapiri mposhi,zm
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06C9ACB8>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -13.97, 'lon': 28.68},
#  'dt': 1603236185,
#  'id': 913029,
#  'main': {'feels_like': 17.05,
#           'grnd_level': 873,
#           'humidity': 32,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 20.13,
#           'temp_max': 20.13,
#           'temp_min': 20.13},
#  'name': 'Kapiri Mposhi',
#  'sys': {'country': 'ZM', 'sunrise': 1603251318, 'sunset': 1603296246},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 85, 'speed': 2.23}}
# duplicate city: colares,pt
# duplicate city: bredasdorp,za
# city: abbeville,fr
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0688A478>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 50.1, 'lon': 1.83},
#  'dt': 1603236185,
#  'id': 3038789,
#  'main': {'feels_like': 10.21,
#           'humidity': 80,
#           'pressure': 1002,
#           'temp': 14.44,
#           'temp_max': 14.44,
#           'temp_min': 14.44},
#  'name': 'Abbeville',
#  'rain': {'1h': 0.55},
#  'sys': {'country': 'FR',
#          'id': 2011713,
#          'sunrise': 1603261483,
#          'sunset': 1603298968,
#          'type': 3},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 166, 'speed': 6.52}}
# duplicate city: longyearbyen,sj
# city: namwala,zm
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06C9E670>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -15.75, 'lon': 26.44},
#  'dt': 1603236186,
#  'id': 901766,
#  'main': {'feels_like': 18.35,
#           'grnd_level': 901,
#           'humidity': 23,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 21.48,
#           'temp_max': 21.48,
#           'temp_min': 21.48},
#  'name': 'Namwala',
#  'sys': {'country': 'ZM', 'sunrise': 1603251766, 'sunset': 1603296873},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 76, 'speed': 1.53}}
# duplicate city: hun,ly
# duplicate city: tabou,ci
# duplicate city: ponta delgada,pt
# duplicate city: atar,mr
# duplicate city: faya,td
# duplicate city: los llanos de aridane,es
# duplicate city: oksfjord,no
# city: rognan,no
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DEF088>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 67.1, 'lon': 15.39},
#  'dt': 1603236186,
#  'id': 3141548,
#  'main': {'feels_like': -7.69,
#           'humidity': 55,
#           'pressure': 1011,
#           'temp': 1.19,
#           'temp_max': 2,
#           'temp_min': 0.56},
#  'name': 'Rognan',
#  'sys': {'country': 'NO',
#          'id': 1615,
#          'sunrise': 1603261263,
#          'sunset': 1603292680,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'speed': 8.7}}
# city: cervo,es
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0685F460>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 43.67, 'lon': -7.41},
#  'dt': 1603236186,
#  'id': 3125287,
#  'main': {'feels_like': 12.85,
#           'humidity': 91,
#           'pressure': 995,
#           'temp': 13.89,
#           'temp_max': 13.89,
#           'temp_min': 13.89},
#  'name': 'Cervo',
#  'rain': {'1h': 0.25},
#  'sys': {'country': 'ES',
#          'id': 2036094,
#          'sunrise': 1603263092,
#          'sunset': 1603301794,
#          'type': 3},
#  'timezone': 7200,
#  'visibility': 9491,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 164, 'speed': 2.56}}
# duplicate city: ushuaia,ar
# duplicate city: bolungarvik,is
# city: arrecife,es
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06854E68>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 28.96, 'lon': -13.55},
#  'dt': 1603235886,
#  'id': 2521570,
#  'main': {'feels_like': 24.6,
#           'humidity': 69,
#           'pressure': 1015,
#           'temp': 24,
#           'temp_max': 24,
#           'temp_min': 24},
#  'name': 'Arrecife',
#  'sys': {'country': 'ES',
#          'id': 2379,
#          'sunrise': 1603263547,
#          'sunset': 1603304285,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 310, 'speed': 3.1}}
# duplicate city: jamestown,sh
# duplicate city: cape town,za
# duplicate city: hermanus,za
# duplicate city: hermanus,za
# duplicate city: georgetown,sh
# duplicate city: illoqqortoormiut,gl
# duplicate city: chuy,uy
# duplicate city: havoysund,no
# duplicate city: georgetown,sh
# duplicate city: klaksvik,fo
# duplicate city: cape town,za
# duplicate city: bredasdorp,za
# duplicate city: sao filipe,cv
# duplicate city: barentsburg,sj
# duplicate city: cape town,za
# duplicate city: hermanus,za
# duplicate city: nouakchott,mr
# city: roros,no
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06DEF0D0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 62.57, 'lon': 11.38},
#  'dt': 1603236187,
#  'id': 3141332,
#  'main': {'feels_like': -7.27,
#           'humidity': 92,
#           'pressure': 999,
#           'temp': -2,
#           'temp_max': -2,
#           'temp_min': -2},
#  'name': 'Røros',
#  'snow': {'1h': 0.19},
#  'sys': {'country': 'NO',
#          'id': 1655,
#          'sunrise': 1603261062,
#          'sunset': 1603294806,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 542,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 120, 'speed': 4.1}}
# duplicate city: aflu,dz
# city: drjanovo,bg
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x06598D18>
# weather data:
#
# {'cod': '404', 'message': 'city not found'}
# duplicate city: ushuaia,ar
# duplicate city: luderitz,na
# duplicate city: bredasdorp,za
# duplicate city: arraial do cabo,br
# duplicate city: cape town,za
# duplicate city: hermanus,za
# duplicate city: vestmannaeyjar,is
# duplicate city: sorvag,fo
# duplicate city: georgetown,sh
# duplicate city: andenes,no
# duplicate city: bubaque,gw
# duplicate city: hermanus,za
# duplicate city: port elizabeth,za
# duplicate city: hofn,is
# duplicate city: vila velha,br
# duplicate city: sistranda,no
# duplicate city: cervo,es
# duplicate city: hermanus,za
# duplicate city: praia,cv
# duplicate city: cape town,za
# duplicate city: loandjili,cg
# duplicate city: hermanus,za
# duplicate city: kruisfontein,za
# duplicate city: cape town,za
# duplicate city: hermanus,za
# duplicate city: cape town,za
# duplicate city: klaksvik,fo
# duplicate city: jamestown,sh
# duplicate city: mrirt,ma
# duplicate city: cape town,za
# duplicate city: tessalit,ml
# duplicate city: araouane,ml
# duplicate city: cape town,za
# duplicate city: cape town,za
# city: kaniama,cd
# Request for http://api.openweathermap.org/data/2.5/weather?<citipy.citipy.City object at 0x0669F0D0>
# weather data:
#
# {'base': 'stations',
#  'clouds': {'all': 87},
#  'cod': 200,
#  'coord': {'lat': -7.57, 'lon': 24.18},
#  'dt': 1603236187,
#  'id': 214389,
#  'main': {'feels_like': 21.12,
#           'grnd_level': 912,
#           'humidity': 97,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 19.2,
#           'temp_max': 19.2,
#           'temp_min': 19.2},
#  'name': 'Kaniama',
#  'sys': {'country': 'CD', 'sunrise': 1603252708, 'sunset': 1603297016},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 347, 'speed': 1.69}}

# %%
lat = list()
city_name = list()
country = list()
humidity = list()
temp = list()
weather_description = list()
wind_speed = list()
cloudiness = list()

try:
    for rec in weather:
        lat.append(rec["coord"]['lat'])
        city_name.append(rec['name'])
        country.append(rec['sys']['country'])
        humidity.append(rec['main']['humidity'])
        temp.append(rec['main']['feels_like'])
        cloudiness.append(rec['clouds']['all'])
        

        try:
            wind_speed.append(rec['wind']['speed'])
        except:
            wind_speed.append(np.nan)
       
       

    weather_data = pd.DataFrame({
        'city_name':city_name,
        'country':country,
        'lat':lat,
        'humidity':humidity,
        'temp':temp,
        'cloudiness':cloudiness, 
        "wind_speed":wind_speed 

    })
except:
    weather_data.csv = weather_data
    df = pd.read_csv('weather_data.csv')
#pd.Series(duplicate_cities).to_csv('duplicates.csv')
#pd.Series(list(weatherless_cities)).to_csv('weatherless.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-98dfb3377883> in <module>
#      10 try:
# ---> 11     for rec in weather:
#      12         lat.append(rec["coord"]['lat'])
#
# NameError: name 'weather' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-98dfb3377883> in <module>
#      36     })
#      37 except:
# ---> 38     weather_data.csv = weather_data
#      39     df = pd.read_csv('weather_data.csv')
#      40 #pd.Series(duplicate_cities).to_csv('duplicates.csv')
#
# NameError: name 'weather_data' is not defined

# %%
weather_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-6c0953ae58e8> in <module>
# ----> 1 weather_data
#
# NameError: name 'weather_data' is not defined

# %%
weather_data.plot(kind="scatter", x="lat", y="temp", 
                  grid=True, figsize=(8,8), 
                  title="Temp vs. Latitude" )

plt.show()
print("Compairing Temperature and Latitude")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-7dcc61ee763c> in <module>
#       1 weather_data.plot(kind="scatter", x="lat", y="temp", grid=True, figsize=(8,8), title="Temp vs. Latitude" )
#       2
# ----> 3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
weather_data.plot(kind="scatter", x="lat", y="humidity", 
                  grid=True, figsize=(8,8), 
                  title="Humidity vs. Latitude")

plt.show()
print("Compairing Humidity vs Latitude")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-9ffb8674935d> in <module>
#       3                   title="Humidity vs. Latitude")
#       4
# ----> 5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
weather_data.plot(kind="scatter", x="lat", y="cloudiness", 
                  grid=True, figsize=(8,8), 
                  title="Cloudiness vs. Latitude" )

plt.show()
print("Compairing cloudiness and latitude")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-a004e74b87cb> in <module>
#       3                   title="Cloudiness vs. Latitude" )
#       4
# ----> 5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
weather_data.plot(kind="scatter", x="lat", y="wind_speed", 
                  grid=True, figsize=(8,8), 
                  title="Windspeed vs. Latitude" )

plt.show()
print("Compairing Windspeed and Latitude")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-7b12c95420a6> in <module>
#       3                   title="Windspeed vs. Latitude" )
#       4
# ----> 5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
x_values = weather_data['lat']
y_values = weather_data['temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="green")
plt.xlabel('Latitude Southern Hemisphere')
plt.ylabel('Tempeture')
plt.show()

# %%
x_values = weather_data['lat']
y_values = weather_data['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="green")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %%
x_values = weather_data['lat']
y_values = weather_data['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="green")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %%
x_values = weather_data['lat']
y_values = weather_data['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="green")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %%
weather_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6c0953ae58e8> in <module>
# ----> 1 weather_data
#
# NameError: name 'weather_data' is not defined
